# %%
set1 = {1,2,3,4,9}
print(set1)
# Out:
# {1, 2, 3, 4, 9}

# %%
set2 = {1,1,1,2,2,3,0,4,4}
print(set2)
# Out:
# {0, 1, 2, 3, 4}

# %%
len(set2)
# Out:
# 5

# %%
set.intersection(set1,set2)
# Out:
# {1, 2, 3, 4}

# %%
set.union(set1,set2)
# Out:
# {0, 1, 2, 3, 4, 9}
